# %%
import pandas as pd

# %%
df_csv = pd.read_csv('open_insider.csv')

# %%
df_excel = pd.read_excel('analyst_recommendations.xlsx', sheet_name=2)

# %%
df_excel
# Out:
#        Unnamed: 0 Unnamed: 1    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0             NaN       S.No  Company Name     Ticker  Benchmark
# 1             NaN          1    3M Company        MMM        SPY
# 2             NaN          2    3M Company        MMM        SPY
# 3             NaN          3    3M Company        MMM        SPY
# 4             NaN          4    3M Company        MMM        SPY
# ...           ...        ...           ...        ...        ...
# 66512         NaN      66512        Zoetis        ZTS        SPY
# 66513         NaN      66513        Zoetis        ZTS        SPY
# 66514         NaN      66514        Zoetis        ZTS        SPY
# 66515         NaN      66515        Zoetis        ZTS        SPY
# 66516         NaN      66516        Zoetis        ZTS        SPY
#
#          Unnamed: 5         Unnamed: 6           Unnamed: 7  \
# 0            Rating        Rating Firm                 Date
# 1           Neutral          Citigroup  2012-07-12 00:00:00
# ...
